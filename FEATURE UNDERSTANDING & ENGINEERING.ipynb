# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/ujwal_nischal'

# %%
os.chdir('/Users/ujwal_nischal/Downloads')

# %%
import pandas as pd
import numpy as num

# %%
d= pd.read_excel('tele.xlsx')

# %%
d
# Out:
#          Column Name                                 Column Description
# 0         customerID                                        Customer ID
# 1             gender                     Customer gender (female, male)
# 2      SeniorCitizen  Whether the customer is a senior citizen or no...
# 3            Partner  Whether the customer has a partner or not (Yes...
# 4         Dependents  Whether the customer has dependents or not (Ye...
# 5             tenure  Number of months the customer has stayed with ...
# 6       PhoneService  Whether the customer has a phone service or no...
# 7      MultipleLines  Whether the customer has multiple lines or not...
# 8    InternetService  Customer’s internet service provider (DSL, Fib...
# 9     OnlineSecurity  Whether the customer has online security or no...
# 10      OnlineBackup  Whether the customer has online backup or not ...
# 11  DeviceProtection  Whether the customer has device protection or ...
# ...

# %%
d1 = pd.read_csv('telco.csv')

# %%
d1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
d1.query("Churn == 'Yes'")['tenure'].mean()
# Out:
# 18.086142322097377

# %%
d1.query("Churn == 'No'")['tenure'].mean()
# Out:
# 37.56996521066873

# %%
d1.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges      202
# Churn                 0
# dtype: int64

# %%
d1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     6841.000000
# mean        0.162147    32.399546       64.588203
# std         0.368612    24.662895       30.513819
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       34.250000
# 50%         0.000000    29.000000       69.800000
# 75%         0.000000    55.000000       90.200000
# max         1.000000   172.000000      118.750000

# %%
d1['MonthlyCharges'].quantile(0.99)
# Out:
# 114.88000000000002

# %%
d1['tenure'].quantile(0.99)
# Out:
# 72.0

# %%
d1.Churn.value_counts()/d1.shape[0]
# Out:
# No     0.73463
# Yes    0.26537
# Name: Churn, dtype: float64

# %%
def dep(x):
      if x=="Yes":
        return "GRADUA"
      elif x==2:
        return "UNIV"
      else:
            return "HIGHSCHOOL"

# %%
pd.crosstab(d1.Churn,d1.Dependents ,)/d1.shape[0]
# Out:
# Dependents        No       Yes
# Churn
# No          0.481329  0.253301
# Yes         0.219083  0.046287

# %%
pd.crosstab(d1.Churn,d1.InternetService,margins=True)/d1.shape[0]
# Out:
# InternetService       DSL  Fiber optic        No      All
# Churn
# No               0.278574     0.255431  0.200625  0.73463
# Yes              0.065171     0.184154  0.016044  0.26537
# All              0.343746     0.439585  0.216669  1.00000

# %%
pd.crosstab(d1.Churn,d1.Contract,margins=True)/d1.shape[0]
# Out:
# Contract  Month-to-month  One year  Two year      All
# Churn
# No              0.315207  0.185574  0.233849  0.73463
# Yes             0.234985  0.023570  0.006815  0.26537
# All             0.550192  0.209144  0.240664  1.00000

# %%
pd.crosstab(d1.Churn,d1.PaymentMethod	,margins=True)/d1.shape[0]
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# Churn
# No                              0.182593                 0.183161
# Yes                             0.036632                 0.032941
# All                             0.219225                 0.216101
#
# PaymentMethod  Electronic check  Mailed check      All
# Churn
# No                     0.183729      0.185148  0.73463
# Yes                    0.152066      0.043731  0.26537
# All                    0.335794      0.228880  1.00000

# %%
d1['MonthlyCharges'] = d1['MonthlyCharges'].fillna(d1['MonthlyCharges'].mean())

# %%
d1['MonthlyCharges'].mean()
# Out:
# 64.58820347902353

# %%
d1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
a = d1['MonthlyCharges'].sum() -202*(d1['MonthlyCharges'].mean())

# %%
b = a/7043

# %%
b - d1['MonthlyCharges'].mean()
# Out:
# -1.8524516687154247

# %%
d1.loc[(d1["Partner"] == "No" and d1["Dependents"]=="No" )] = 72

# %%
d1.tenure.mean()
# Out:
# 32.37114865824223

# %%
def categorise(row):  
    if row[''] > 0 and row['colC'] <= 99:
        return 'A'

# %%
d1['Flags'] = d1.apply(lambda row: categorise(row), axis=1)

# %%
d1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
pd.crosstab(d1.Churn,d1.Flags,margins=True)/d1.shape[0]
# Out:
# Flags         0         1      All
# Churn
# No     0.521653  0.212977  0.73463
# Yes    0.230016  0.035354  0.26537
# All    0.751668  0.248332  1.00000

# %%
def get_contract(x):
    if x == "Month-to-month":
        return 1
    else:
        return 0

# %%
d1['C'] = d1['Contract'].map(get_contract)

# %%
d1['C'].value_counts()
# Out:
# 1    3875
# 0    3168
# Name: C, dtype: int64

# %%
def bucket(x):
    if x < 12:
        return "Short"
    elif x > 12 and x < 36:
        return "medium"
    else:
        return "Long"

# %%
d1['tenurebkt'] = d1["tenure"].map(bucket)

# %%
d1['tenurebkt'].value_counts()
# Out:
# Long      3168
# Short     2069
# medium    1806
# Name: tenurebkt, dtype: int64

# %%
def cnt(x):
    if x['Contract'] == "Month-to-month" and x['tenure'] < 12:
        return 1
    else :
        return 0

# %%
d1['Short_Contracts'] = d1.apply(lambda row: cnt(row), axis=1)

# %%
d1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingMovies  \
# 0  No phone service             DSL             No  ...              No
# 1                No             DSL            Yes  ...              No
# 2                No             DSL            Yes  ...              No
# 3  No phone service             DSL            Yes  ...              No
# 4                No     Fiber optic             No  ...              No
#
# ...

# %%
pd.crosstab(d1.Churn,d1.Short_Contracts,margins=True)/d1.shape[0]
# Out:
# Short_Contracts         0         1      All
# Churn
# No               0.604430  0.130200  0.73463
# Yes              0.124663  0.140707  0.26537
# All              0.729093  0.270907  1.00000

# %%
def elec_check(x):
    if x['PaymentMethod'] == "Electronic check":
        return 1
    else:
        return 0

# %%
d1['elec_check'] = d1.apply(lambda row: elec_check(row), axis=1)

# %%
pd.crosstab(d1.Churn,d1.elec_check,margins=True)/d1.shape[0]
# Out:
# elec_check         0         1      All
# Churn
# No          0.550902  0.183729  0.73463
# Yes         0.113304  0.152066  0.26537
# All         0.664206  0.335794  1.00000

# %%
def get_contract(x):
    if (x['OnlineSecurity'] and x['TechSupport'] and x['DeviceProtection'] and x['OnlineBackup']) == "No":
        return 1
    else:
        return 0

# %%
d1['N'] = d1.apply(lambda row: get_contract(row), axis=1)

# %%
pd.crosstab(d1.Churn,d1.N,margins=True)/d1.shape[0]
# Out:
# N             0         1      All
# Churn
# No     0.471248  0.263382  0.73463
# Yes    0.090302  0.175067  0.26537
# All    0.561550  0.438450  1.00000

# %%
def get_contract(x):
    if x['MonthlyCharges'] > 55 :
        return 1
    else:
        return 0

# %%
d1["High_Monthly_Charges"] =d1.apply(lambda row: get_contract(row), axis=1)

# %%
pd.crosstab(d1.Churn,d1.High_Monthly_Charges,margins=True)/d1.shape[0]
# Out:
# High_Monthly_Charges         0         1      All
# Churn
# No                    0.311231  0.423399  0.73463
# Yes                   0.062473  0.202896  0.26537
# All                   0.373704  0.626296  1.00000
